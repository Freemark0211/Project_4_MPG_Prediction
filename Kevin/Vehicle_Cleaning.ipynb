# %%
import pandas as pd
import numpy as np
import requests as rq
import json as js
import datetime as dt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
import math
from sklearn.svm import SVC

# %%
vehicles_df = pd.read_csv('Resources/vehicles.csv', low_memory=False)
vehicles_df
# Out:
#        barrels08  barrelsA08  charge120  charge240  city08  city08U  cityA08  \
# 0      14.167143         0.0        0.0        0.0      19      0.0        0
# 1      27.046364         0.0        0.0        0.0       9      0.0        0
# 2      11.018889         0.0        0.0        0.0      23      0.0        0
# 3      27.046364         0.0        0.0        0.0      10      0.0        0
# 4      15.658421         0.0        0.0        0.0      17      0.0        0
# ...          ...         ...        ...        ...     ...      ...      ...
# 46559  13.523182         0.0        0.0        0.0      19      0.0        0
# 46560  12.935217         0.0        0.0        0.0      20      0.0        0
# 46561  14.167143         0.0        0.0        0.0      18      0.0        0
# 46562  14.167143         0.0        0.0        0.0      18      0.0        0
# 46563  16.528333         0.0        0.0        0.0      16      0.0        0
#
#        cityA08U  cityCD  cityE  ...  mfrCode  c240Dscr  charge240b  c240bDscr  \
# 0           0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 1           0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 2           0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 3           0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 4           0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# ...         ...     ...    ...  ...      ...       ...         ...        ...
# 46559       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 46560       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 46561       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 46562       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 46563       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
#
#                           createdOn                    modifiedOn  startStop  \
# 0      Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 1      Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 2      Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 3      Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 4      Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# ...                             ...                           ...        ...
# 46559  Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 46560  Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 46561  Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 46562  Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 46563  Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
#
#        phevCity  phevHwy  phevComb
# 0             0        0         0
# 1             0        0         0
# 2             0        0         0
# 3             0        0         0
# 4             0        0         0
# ...         ...      ...       ...
# 46559         0        0         0
# 46560         0        0         0
# 46561         0        0         0
# 46562         0        0         0
# 46563         0        0         0
#
# [46564 rows x 84 columns]

# %%
vehicles_df.columns.values
# Out:
# array(['barrels08', 'barrelsA08', 'charge120', 'charge240', 'city08',
#        'city08U', 'cityA08', 'cityA08U', 'cityCD', 'cityE', 'cityUF',
#        'co2', 'co2A', 'co2TailpipeAGpm', 'co2TailpipeGpm', 'comb08',
#        'comb08U', 'combA08', 'combA08U', 'combE', 'combinedCD',
#        'combinedUF', 'cylinders', 'displ', 'drive', 'engId', 'eng_dscr',
#        'feScore', 'fuelCost08', 'fuelCostA08', 'fuelType', 'fuelType1',
#        'ghgScore', 'ghgScoreA', 'highway08', 'highway08U', 'highwayA08',
#        'highwayA08U', 'highwayCD', 'highwayE', 'highwayUF', 'hlv', 'hpv',
#        'id', 'lv2', 'lv4', 'make', 'model', 'mpgData', 'phevBlended',
#        'pv2', 'pv4', 'range', 'rangeCity', 'rangeCityA', 'rangeHwy',
#        'rangeHwyA', 'trany', 'UCity', 'UCityA', 'UHighway', 'UHighwayA',
#        'VClass', 'year', 'youSaveSpend', 'baseModel', 'guzzler',
#        'trans_dscr', 'tCharger', 'sCharger', 'atvType', 'fuelType2',
#        'rangeA', 'evMotor', 'mfrCode', 'c240Dscr', 'charge240b',
#        'c240bDscr', 'createdOn', 'modifiedOn', 'startStop', 'phevCity',
#        'phevHwy', 'phevComb'], dtype=object)

# %%
vc = vehicles_df.atvType.value_counts()
vc.sum()
# Out:
# 4890

# %%
vehicles_df = vehicles_df[vehicles_df.atvType.isnull()]
vehicles_df
# Out:
#        barrels08  barrelsA08  charge120  charge240  city08  city08U  cityA08  \
# 0      14.167143         0.0        0.0        0.0      19      0.0        0
# 1      27.046364         0.0        0.0        0.0       9      0.0        0
# 2      11.018889         0.0        0.0        0.0      23      0.0        0
# 3      27.046364         0.0        0.0        0.0      10      0.0        0
# 4      15.658421         0.0        0.0        0.0      17      0.0        0
# ...          ...         ...        ...        ...     ...      ...      ...
# 46559  13.523182         0.0        0.0        0.0      19      0.0        0
# 46560  12.935217         0.0        0.0        0.0      20      0.0        0
# 46561  14.167143         0.0        0.0        0.0      18      0.0        0
# 46562  14.167143         0.0        0.0        0.0      18      0.0        0
# 46563  16.528333         0.0        0.0        0.0      16      0.0        0
#
#        cityA08U  cityCD  cityE  ...  mfrCode  c240Dscr  charge240b  c240bDscr  \
# 0           0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 1           0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 2           0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 3           0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 4           0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# ...         ...     ...    ...  ...      ...       ...         ...        ...
# 46559       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 46560       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 46561       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 46562       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 46563       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
#
#                           createdOn                    modifiedOn  startStop  \
# 0      Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 1      Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 2      Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 3      Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 4      Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# ...                             ...                           ...        ...
# 46559  Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 46560  Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 46561  Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 46562  Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 46563  Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
#
#        phevCity  phevHwy  phevComb
# 0             0        0         0
# 1             0        0         0
# 2             0        0         0
# 3             0        0         0
# 4             0        0         0
# ...         ...      ...       ...
# 46559         0        0         0
# 46560         0        0         0
# 46561         0        0         0
# 46562         0        0         0
# 46563         0        0         0
#
# [41674 rows x 84 columns]

# %%
veh_reduced = vehicles_df[['year','VClass','comb08','cylinders','displ','drive','fuelType','trany']]
veh_reduced
# Out:
#        year           VClass  comb08  cylinders  displ  \
# 0      1985      Two Seaters      21        4.0    2.0
# 1      1985      Two Seaters      11       12.0    4.9
# 2      1985  Subcompact Cars      27        4.0    2.2
# 3      1985             Vans      11        8.0    5.2
# 4      1993     Compact Cars      19        4.0    2.2
# ...     ...              ...     ...        ...    ...
# 46559  1993     Compact Cars      22        4.0    2.2
# 46560  1993     Compact Cars      23        4.0    2.2
# 46561  1993     Compact Cars      21        4.0    2.2
# 46562  1993     Compact Cars      21        4.0    2.2
# 46563  1993     Compact Cars      18        4.0    2.2
#
#                             drive fuelType            trany
# 0                Rear-Wheel Drive  Regular     Manual 5-spd
# 1                Rear-Wheel Drive  Regular     Manual 5-spd
# 2               Front-Wheel Drive  Regular     Manual 5-spd
# 3                Rear-Wheel Drive  Regular  Automatic 3-spd
# 4      4-Wheel or All-Wheel Drive  Premium     Manual 5-spd
# ...                           ...      ...              ...
# 46559           Front-Wheel Drive  Regular  Automatic 4-spd
# 46560           Front-Wheel Drive  Regular     Manual 5-spd
# 46561  4-Wheel or All-Wheel Drive  Regular  Automatic 4-spd
# 46562  4-Wheel or All-Wheel Drive  Regular     Manual 5-spd
# 46563  4-Wheel or All-Wheel Drive  Premium  Automatic 4-spd
#
# [41674 rows x 8 columns]

# %%
# veh_reduced['startStop'] = veh_reduced['startStop'].fillna('N')
# veh_reduced.head()

# %%
veh_reduced.dropna(how = 'any', inplace = True)
veh_reduced
# Out:
# C:\Users\kmill\AppData\Local\Temp\ipykernel_26184\4184643121.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   veh_reduced.dropna(how = 'any', inplace = True)
#        year           VClass  comb08  cylinders  displ  \
# 0      1985      Two Seaters      21        4.0    2.0
# 1      1985      Two Seaters      11       12.0    4.9
# 2      1985  Subcompact Cars      27        4.0    2.2
# 3      1985             Vans      11        8.0    5.2
# 4      1993     Compact Cars      19        4.0    2.2
# ...     ...              ...     ...        ...    ...
# 46559  1993     Compact Cars      22        4.0    2.2
# 46560  1993     Compact Cars      23        4.0    2.2
# 46561  1993     Compact Cars      21        4.0    2.2
# 46562  1993     Compact Cars      21        4.0    2.2
# 46563  1993     Compact Cars      18        4.0    2.2
#
#                             drive fuelType            trany
# 0                Rear-Wheel Drive  Regular     Manual 5-spd
# 1                Rear-Wheel Drive  Regular     Manual 5-spd
# 2               Front-Wheel Drive  Regular     Manual 5-spd
# 3                Rear-Wheel Drive  Regular  Automatic 3-spd
# 4      4-Wheel or All-Wheel Drive  Premium     Manual 5-spd
# ...                           ...      ...              ...
# 46559           Front-Wheel Drive  Regular  Automatic 4-spd
# 46560           Front-Wheel Drive  Regular     Manual 5-spd
# 46561  4-Wheel or All-Wheel Drive  Regular  Automatic 4-spd
# 46562  4-Wheel or All-Wheel Drive  Regular     Manual 5-spd
# 46563  4-Wheel or All-Wheel Drive  Premium  Automatic 4-spd
#
# [40585 rows x 8 columns]

# %%
veh_reduced.dtypes
# Out:
# year           int64
# VClass        object
# comb08         int64
# cylinders    float64
# displ        float64
# drive         object
# fuelType      object
# trany         object
# dtype: object

# %%
sorted = veh_reduced.sort_values(by='year', axis=0, ascending=True)
sorted
# Out:
#        year                           VClass  comb08  cylinders  displ  \
# 19453  1984         Special Purpose Vehicles      15        4.0    2.0
# 19140  1984       Standard Pickup Trucks 4WD      14        6.0    4.1
# 20316  1984      Special Purpose Vehicle 4WD      18        6.0    4.2
# 19139  1984       Standard Pickup Trucks 4WD      15        6.0    4.1
# 19136  1984       Standard Pickup Trucks 2WD      21        4.0    2.4
# ...     ...                              ...     ...        ...    ...
# 40233  2024  Small Sport Utility Vehicle 4WD      22        4.0    2.0
# 40232  2024  Small Sport Utility Vehicle 4WD      22        4.0    2.0
# 40231  2024  Small Sport Utility Vehicle 4WD      20        4.0    2.0
# 40275  2024                  Subcompact Cars      19        6.0    3.0
# 40105  2024                  Subcompact Cars      27        4.0    2.0
#
#                             drive fuelType            trany
# 19453               2-Wheel Drive  Regular     Manual 4-spd
# 19140  4-Wheel or All-Wheel Drive  Regular     Manual 4-spd
# 20316  4-Wheel or All-Wheel Drive  Regular     Manual 5-spd
# 19139  4-Wheel or All-Wheel Drive  Regular  Automatic 4-spd
# 19136               2-Wheel Drive  Regular     Manual 5-spd
# ...                           ...      ...              ...
# 40233             All-Wheel Drive  Regular   Automatic (S8)
# 40232             All-Wheel Drive  Regular   Automatic (S8)
# 40231             All-Wheel Drive  Regular   Automatic (S8)
# 40275            Rear-Wheel Drive  Premium     Manual 6-spd
# 40105           Front-Wheel Drive  Premium     Manual 6-spd
#
# [40585 rows x 8 columns]

# %%
sorted.to_csv("Resources/vehicles_basic_clean.csv",index=False)

# %%
# counts of each makes' appearance in table

# make_counts = veh_reduced.make.value_counts()
# make_counts.head(5)

# %%
# make_counts_df = make_counts.to_frame()
# make_counts_df = make_counts_df[make_counts_df["make"]>10]
# make_counts_df

# %%
# # list of makes to keep
# make_list = make_counts_df.index.tolist()

# # remove small makes
# sorted_reduced = sorted[sorted.make.isin(make_list)]
# sorted_reduced

# %%
VClass_counts = sorted.VClass.value_counts()
VClass_counts.sort_index()
# Out:
# Compact Cars                          5610
# Large Cars                            2171
# Midsize Cars                          4714
# Midsize Station Wagons                 455
# Midsize-Large Station Wagons           619
# Minicompact Cars                      1520
# Minivan - 2WD                          330
# Minivan - 4WD                           54
# Small Pickup Trucks                    498
# Small Pickup Trucks 2WD                447
# Small Pickup Trucks 4WD                271
# Small Sport Utility Vehicle 2WD        843
# Small Sport Utility Vehicle 4WD       1391
# Small Station Wagons                  1498
# Special Purpose Vehicle 2WD            686
# Special Purpose Vehicle 4WD            323
# Special Purpose Vehicles              1408
# Special Purpose Vehicles/2wd             2
# Special Purpose Vehicles/4wd             2
# Sport Utility Vehicle - 2WD           1414
# Sport Utility Vehicle - 4WD           1858
# Standard Pickup Trucks                2140
# Standard Pickup Trucks 2WD            1100
# Standard Pickup Trucks 4WD            1077
# Standard Pickup Trucks/2wd               4
# Standard Sport Utility Vehicle 2WD     339
# Standard Sport Utility Vehicle 4WD     871
# Subcompact Cars                       5055
# Two Seaters                           2261
# Vans                                  1079
# Vans Passenger                           2
# Vans, Cargo Type                       319
# Vans, Passenger Type                   224
# Name: VClass, dtype: int64

# %%
# function to automate reductions

def clean_up(df, column, replace):
    
    for c in replace:
        df.loc[vr[column].str.contains(c), column] = c

# %%
# reduce VClasses

vr = sorted.copy()
class_search_values = ["Minivan", "Small Pickup Trucks", "Special Purpose Vehicle", "Sport Utility Vehicle",\
                      "Standard Pickup Trucks","Vans", "Small Sport Utility Vehicle", "Standard Sport Utility Vehicle"]

# for c in class_search_values:
#     vr.loc[vr["VClass"].str.contains(c), "VClass"] = c
clean_up(vr, "VClass", class_search_values)    
    
vr.loc[vr["VClass"].str.contains("Midsize Station"), "VClass"] = "Midsize-Large Station Wagons"
    
vr["VClass"].value_counts()
# Out:
# Sport Utility Vehicle           6716
# Compact Cars                    5610
# Subcompact Cars                 5055
# Midsize Cars                    4714
# Standard Pickup Trucks          4321
# Special Purpose Vehicle         2421
# Two Seaters                     2261
# Large Cars                      2171
# Vans                            1624
# Minicompact Cars                1520
# Small Station Wagons            1498
# Small Pickup Trucks             1216
# Midsize-Large Station Wagons    1074
# Minivan                          384
# Name: VClass, dtype: int64

# %%
# reduce to 4, front or rear drive

vr.loc[vr["drive"].str.contains("2-Wheel Drive"), "drive"] = "Front-Wheel Drive"
# vr.loc[vr["drive"].str.contains("Rear-Wheel"), "drive"] = "2-Wheel Drive"
vr.loc[vr["drive"].str.contains("All-Wheel"), "drive"] = "4-Wheel Drive"
vr.loc[vr["drive"].str.contains("Part-time"), "drive"] = "4-Wheel Drive"
drive_counts = vr.drive.value_counts()
drive_counts.sort_index()
# Out:
# 4-Wheel Drive        12267
# Front-Wheel Drive    14550
# Rear-Wheel Drive     13768
# Name: drive, dtype: int64

# %%
# reduce to automatic or manual

AorM = ["Automatic", "Manual"]

clean_up(vr, "trany", AorM )

trany_counts = vr.trany.value_counts()
trany_counts.sort_index()
# Out:
# Automatic    28326
# Manual       12259
# Name: trany, dtype: int64

# %%
fuel_count = vr.fuelType.value_counts()
fuel_count
# Out:
# Regular     26865
# Premium     13558
# Midgrade      143
# CNG            10
# Diesel          9
# Name: fuelType, dtype: int64

# %%
# remove non-gasoline fuels

vr = vr[(vr.fuelType == "Regular") | (vr.fuelType == "Premium")]
vr
# Out:
#        year                   VClass  comb08  cylinders  displ  \
# 19453  1984  Special Purpose Vehicle      15        4.0    2.0
# 19140  1984   Standard Pickup Trucks      14        6.0    4.1
# 20316  1984  Special Purpose Vehicle      18        6.0    4.2
# 19139  1984   Standard Pickup Trucks      15        6.0    4.1
# 19136  1984   Standard Pickup Trucks      21        4.0    2.4
# ...     ...                      ...     ...        ...    ...
# 40233  2024    Sport Utility Vehicle      22        4.0    2.0
# 40232  2024    Sport Utility Vehicle      22        4.0    2.0
# 40231  2024    Sport Utility Vehicle      20        4.0    2.0
# 40275  2024          Subcompact Cars      19        6.0    3.0
# 40105  2024          Subcompact Cars      27        4.0    2.0
#
#                    drive fuelType      trany
# 19453  Front-Wheel Drive  Regular     Manual
# 19140      4-Wheel Drive  Regular     Manual
# 20316      4-Wheel Drive  Regular     Manual
# 19139      4-Wheel Drive  Regular  Automatic
# 19136  Front-Wheel Drive  Regular     Manual
# ...                  ...      ...        ...
# 40233      4-Wheel Drive  Regular  Automatic
# 40232      4-Wheel Drive  Regular  Automatic
# 40231      4-Wheel Drive  Regular  Automatic
# 40275   Rear-Wheel Drive  Premium     Manual
# 40105  Front-Wheel Drive  Premium     Manual
#
# [40423 rows x 8 columns]

# %%
vr = vr.drop("fuelType", axis=1)

# %%
vr = vr.rename(columns={"comb08": "MPG(comb)", "VClass": "vehicle_class","displ":"displ (L)"})
vr
# Out:
#        year            vehicle_class  MPG(comb)  cylinders  displ (L)  \
# 19453  1984  Special Purpose Vehicle         15        4.0        2.0
# 19140  1984   Standard Pickup Trucks         14        6.0        4.1
# 20316  1984  Special Purpose Vehicle         18        6.0        4.2
# 19139  1984   Standard Pickup Trucks         15        6.0        4.1
# 19136  1984   Standard Pickup Trucks         21        4.0        2.4
# ...     ...                      ...        ...        ...        ...
# 40233  2024    Sport Utility Vehicle         22        4.0        2.0
# 40232  2024    Sport Utility Vehicle         22        4.0        2.0
# 40231  2024    Sport Utility Vehicle         20        4.0        2.0
# 40275  2024          Subcompact Cars         19        6.0        3.0
# 40105  2024          Subcompact Cars         27        4.0        2.0
#
#                    drive      trany
# 19453  Front-Wheel Drive     Manual
# 19140      4-Wheel Drive     Manual
# 20316      4-Wheel Drive     Manual
# 19139      4-Wheel Drive  Automatic
# 19136  Front-Wheel Drive     Manual
# ...                  ...        ...
# 40233      4-Wheel Drive  Automatic
# 40232      4-Wheel Drive  Automatic
# 40231      4-Wheel Drive  Automatic
# 40275   Rear-Wheel Drive     Manual
# 40105  Front-Wheel Drive     Manual
#
# [40423 rows x 7 columns]

# %%
vr.to_csv("Resources/vehicles_fully_reduced_2.csv",index=False)

# %%
# remove special purpose vehicles
vrsp = vr[vr['vehicle_class'] != 'Special Purpose Vehicle']
vrsp.to_csv("Resources/vehicles_fully_reduced_no_sp.csv",index=False)

# %%
years = vrsp.groupby(['year'])['MPG(comb)'].mean()
years
# Out:
# year
# 1984    15.985075
# 1985    19.718935
# 1986    19.659319
# 1987    19.517143
# 1988    19.718053
# 1989    19.498477
# 1990    19.344262
# 1991    19.128497
# 1992    19.186583
# 1993    19.483871
# 1994    19.461443
# 1995    19.292441
# 1996    19.981102
# 1997    19.896382
# 1998    19.841600
# 1999    19.244873
# 2000    19.169345
# 2001    19.079769
# 2002    18.950270
# 2003    18.771429
# 2004    18.967339
# 2005    19.005510
# 2006    18.786398
# 2007    18.987512
# 2008    19.191781
# 2009    19.738095
# 2010    20.464100
# 2011    20.861050
# 2012    21.464989
# 2013    22.321311
# 2014    22.360084
# 2015    22.507232
# 2016    22.820019
# 2017    22.908587
# 2018    22.931189
# 2019    22.848954
# 2020    22.743083
# 2021    22.416925
# 2022    22.290832
# 2023    22.151653
# 2024    22.768987
# Name: MPG(comb), dtype: float64

# %%
cyl = vrsp[vrsp['cylinders'] = 3]
cyl.sort_values(by = 'MPG(comb)').head(30)
# Out:
#        year    vehicle_class  MPG(comb)  cylinders  displ (L)  \
# 41307  1989      Two Seaters          7       12.0        5.2
# 34522  1988      Two Seaters          7       12.0        5.2
# 21057  1987      Two Seaters          7       12.0        5.2
# 42581  1990      Two Seaters          7       12.0        5.2
# 7901   1986      Two Seaters          7       12.0        5.2
# 27193  1987       Large Cars          8        8.0        6.8
# 45003  1992      Two Seaters          8        8.0        6.0
# 30635  1985     Compact Cars          8        8.0        6.8
# 23199  1987  Subcompact Cars          8        8.0        6.8
# 25346  1987     Compact Cars          8        8.0        6.8
# 40670  1985  Subcompact Cars          8        8.0        5.3
# 41776  1985       Large Cars          8        8.0        6.8
# 40787  1985  Subcompact Cars          8        8.0        5.3
# 11734  1986     Compact Cars          8        8.0        6.8
# 2002   1985  Subcompact Cars          8        8.0        5.3
# 13641  1986       Large Cars          8        8.0        6.8
# 13774  1985  Subcompact Cars          8        8.0        6.8
# 1770   1995      Two Seaters          8       12.0        4.7
# 10123  1986  Subcompact Cars          8        8.0        6.8
# 23221  1987  Subcompact Cars          8        8.0        6.8
# 9229   2003      Two Seaters          8       12.0        6.0
# 12853  1986     Midsize Cars          8        8.0        4.9
# 46196  1993      Two Seaters          8        8.0        6.0
# 26867  1987     Midsize Cars          8        8.0        6.8
# 26834  1987     Midsize Cars          8        8.0        6.8
# 23166  1987  Subcompact Cars          8        8.0        6.8
# 1990   1985  Subcompact Cars          8        8.0        5.3
# 40898  1985  Subcompact Cars          8        8.0        5.3
# 40910  1985     Midsize Cars          8        8.0        4.9
# 1979   1985  Subcompact Cars          8        8.0        5.3
#
#                   drive      trany
# 41307  Rear-Wheel Drive     Manual
# 34522  Rear-Wheel Drive     Manual
# 21057  Rear-Wheel Drive     Manual
# 42581  Rear-Wheel Drive     Manual
# 7901   Rear-Wheel Drive     Manual
# 27193  Rear-Wheel Drive  Automatic
# 45003  Rear-Wheel Drive  Automatic
# 30635  Rear-Wheel Drive  Automatic
# 23199  Rear-Wheel Drive  Automatic
# 25346  Rear-Wheel Drive  Automatic
# 40670  Rear-Wheel Drive  Automatic
# 41776  Rear-Wheel Drive  Automatic
# 40787  Rear-Wheel Drive  Automatic
# 11734  Rear-Wheel Drive  Automatic
# 2002   Rear-Wheel Drive     Manual
# 13641  Rear-Wheel Drive  Automatic
# 13774  Rear-Wheel Drive  Automatic
# 1770   Rear-Wheel Drive     Manual
# 10123  Rear-Wheel Drive  Automatic
# 23221  Rear-Wheel Drive  Automatic
# 9229   Rear-Wheel Drive  Automatic
# 12853  Rear-Wheel Drive  Automatic
# 46196  Rear-Wheel Drive  Automatic
# 26867  Rear-Wheel Drive  Automatic
# 26834  Rear-Wheel Drive  Automatic
# 23166  Rear-Wheel Drive  Automatic
# 1990   Rear-Wheel Drive  Automatic
# 40898  Rear-Wheel Drive     Manual
# 40910  Rear-Wheel Drive  Automatic
# 1979   Rear-Wheel Drive  Automatic

# %%
#cyl.to_csv("Resources/vehicles_fully_reduced_no_sp.csv",index=False)

# %%
disp = vr[vr['displ (L)'] == 1.0]
disp
# Out:
#        year            vehicle_class  MPG(comb)  cylinders  displ (L)  \
# 19040  1984      Small Pickup Trucks         22        4.0        1.0
# 19024  1984      Small Pickup Trucks         19        4.0        1.0
# 19439  1984  Special Purpose Vehicle         22        4.0        1.0
# 19440  1984  Special Purpose Vehicle         22        4.0        1.0
# 29641  1985         Minicompact Cars         42        3.0        1.0
# ...     ...                      ...        ...        ...        ...
# 32531  2018             Compact Cars         31        3.0        1.0
# 32532  2018             Compact Cars         34        3.0        1.0
# 33973  2019    Sport Utility Vehicle         28        3.0        1.0
# 34764  2020    Sport Utility Vehicle         28        3.0        1.0
# 36440  2021    Sport Utility Vehicle         28        3.0        1.0
#
#                    drive      trany
# 19040      4-Wheel Drive     Manual
# 19024      4-Wheel Drive     Manual
# 19439      4-Wheel Drive     Manual
# 19440      4-Wheel Drive     Manual
# 29641  Front-Wheel Drive     Manual
# ...                  ...        ...
# 32531  Front-Wheel Drive  Automatic
# 32532  Front-Wheel Drive     Manual
# 33973  Front-Wheel Drive  Automatic
# 34764  Front-Wheel Drive  Automatic
# 36440  Front-Wheel Drive  Automatic
#
# [160 rows x 7 columns]

# %%
# Out:
# vehicle_class
# False    20.454632
# True     19.187085
# Name: MPG(comb), dtype: float64
